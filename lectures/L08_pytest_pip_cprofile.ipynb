# %% [markdown]
# # Code development: pytest and pip
#
# *Davide Gerosa (Milano-Bicocca)*
#
# **Sources**:
#  - Michael Zingale at Stony Brook University: https://sbu-python-class.github.io
#  - Googling around (a lot); my own research.

# %% [markdown]
# Plan for today. I'd like to showcase three more things you might need in your research in computational physics.
#
# - **Part 1**. Package and share your code   -> make the code publicly available
# - **Part 2**. Testing done right
# - **Part 3**. Find the bottleneck

# %% [markdown]
# # Part 1. Package and share your code

# %%
import os, sys

# %% [markdown]
# So far, we've been writing our code all in Jupyter.  But when it comes
# time to write code that we want to reuse, we want to put it into a
# standalone `*.py` file. Produce a good code is like a prosecution of a computational physicist CV.
#
# Then we can load it on in python (or Jupyter) and use the capabilities
# it provides or make it a standalone program that can be run from the
# command line.
#
# Jupyter is great for interactive explorations and sharing your workflow with others
# in a self-contained way.  But if there is an operation that you do over and over,
# you should put it into a separate module that you import.  That way you only need to
# maintain and debug a single instance of the function, and all your workflows can reuse it.
#
#
# ## Editors
#
# Use your preferred editors. Some popular ones include:
#
# * VS Code: https://code.visualstudio.com/
# * spyder: https://www.spyder-ide.org/
# * emacs / vi
#
# Rest in peace [Atom](https://github.blog/2022-06-08-sunsetting-atom/), you were the best.
#
#
# ## Standalone module
#
# Here's a very simple module (lets call it `hello.py`):
#
# ```python
# def hello():
#     print("hello")
#
# if __name__ == "__main__":
#     hello()
# ```
#
# There are two ways we can use this.
#
# * Inside of python (or jupyter), we can do:
#
#   ```python
#   import hello
#   hello.hello()
#   ```
#
# * From the command line, we can do:
#
#   ```python
#   python hello.py
#   ```
#
# Additionally, on a Unix system, we can add:
#
# ```python
# #!/usr/bin/env python3
# ```
#
# to the top and then mark the file as executable, via:
#
# ```bash
# chmod a+x hello.py
# ```
#
# allowing us to execute it simply as:
#
# ```bash
# ./hello.py
# ```
#
# Here we see how the `__name__` variable is treated by python:
#
# * If we import our module into python, then `__name__` is set to the module name
# * If we run the module from the command line, then `__name__` is set to `__main__`
#
# The module has to be manually re-imported.
#
#
# ## Changing module contents
#
# If we make changes to our module file, then we need to re-import it.  This can be done as:
#
# ```python
# import importlib
# example = importlib.reload(example)
# ```

# %% [markdown]
# # Command line arguments
#
# For standalone programs, we often want to have our program take
# command line arguments that affect the runtime behavior of our
# program.  There are a variety of mechanisms to do this in python, but
# the best option is the [argparse
# module](https://docs.python.org/3/library/argparse.html).
#
# Here's an example of using `argparse` to take a variety of options:

# %%
# %load argparse_example.py    

# import the module

# %% [markdown]
# ```python
# #!/usr/bin/env python3
#
# # to get usage: use -h
# import argparse
#
#
# def setup_args():
#
#     # simple example of argparse: add an argument paserser with the parameter for the user
#
#     parser = argparse.ArgumentParser()
#     parser.add_argument("-a", help="the -a option", action="store_true")
#     parser.add_argument("-b", help="-b takes a number", type=int, default=0)
#     parser.add_argument("-c", help="-c takes a string", type=str, default=None)
#     parser.add_argument("--darg", help="the --darg option", action="store_true")
#     parser.add_argument("--earg", help="--earg takes a string", type=str, metavar="test",
#                         default="example string")
#
#     # extra arguments (positional)
#     parser.add_argument("extras", metavar="extra", type=str, nargs="*",
#                         help="optional positional arguments")
#
#     return parser.parse_args()
#
#
# # check
# if __name__ == "__main__":
#
#     args = setup_args()
#
#
#     if args.a:
#         print("-a set")
#     print(f"-b = {args.b}")
#     print(f"-c = {args.c}")
#     if args.darg:
#         print("--dargs set")
#     print(f"--earg value = {args.earg}")
#
#     print(" ")
#     print("extra positional arguments: ")
#     if len(args.extras) > 0:
#         for e in args.extras:
#             print(e)
# ```

# %% [markdown]
# A nice feature of `argparse` is that it automatically generates help for us.  If
# we place the above code in `argparse_example.py` then we can do:

# %%
os.system('python argparse_example.py --help');
# Out:
# usage: argparse_example.py [-h] [-a] [-b B] [-c C] [--darg] [--earg test]
#                            [extra ...]
#
# positional arguments:
#   extra        optional positional arguments
#
# options:
#   -h, --help   show this help message and exit
#   -a           the -a option
#   -b B         -b takes a number
#   -c C         -c takes a string
#   --darg       the --darg option
#   --earg test  --earg takes a string

# %% [markdown]
# # Paths
#
# How does python find modules?  It has a [search order](https://docs.python.org/3/tutorial/modules.html#the-module-search-path):
#
# * current directory
#
# * `PYTHONPATH` environment variable (this follows the same format as
#   the shell `PATH` environment variable). This variable can be empty.
#
# * System-wide python installation default path (usually has a
#   `site-packages` directory)
#
# We can look at the path via ``sys.path``.  On my machine I get:

# %%
sys.path

# search order in which python goes for searching paths
# Out:
# ['/usr/lib/python312.zip',
#  '/usr/lib/python3.12',
#  '/usr/lib/python3.12/lib-dynload',
#  '',
#  '/home/michele/python_env/lib/python3.12/site-packages']

# %% [markdown]
# My PYTHONPATH is empty...

# %%
os.system('echo $PYTHONPATH')     # specify a python path (0 if not specifyed)
# Out:
# 0

# %% [markdown]
# You can add things explicitly to my the `PYTHONPATH` shell variable.
#
# Using `PYTHONPATH` to quickly add a module to your search path is an easy hack,
# but if you are developing a library that will be used by others, it is better
# to make the modules installable to the system search paths.  This is where
# _packaging_ comes into play.

# %% [markdown]
# # Packaging
#
# Making my packs installable.
#
# Let's look at the structure of creating an installable python package.
# The python packaging system is constantly evolving, and the current recommendations
# of tools is list here: https://packaging.python.org/en/latest/guides/tool-recommendations/
#
# Eventually, you'll want people to do  `pip install myawesomepackage`. One thing at the time...
#
#
# ## Our example
#
# We'll work on an example that builds on the Mandelbrot set exercise
# from the matplotlib session.  Our example is hosted here:
#
# https://github.com/dgerosa/scientificcomputing_bicocca_2025/tree/main/lectures/modulescicompclass
#
# The directory structure appears as:
#
# ```
# modulescicompclass        # dir in local where you work
# ├── modulescicompclass    # same name of the parent dir, which contains the code. In importing, this works as the namespace
# │   ├── __init__.py       # file that must be there, also empty, in order to python recognise the dir as a module
# │   └── mandel.py         # actual code
# └── README.md             # for cosmetic, in the outer dir
# └── setup.py              # instruction to uplode your module and metadata
# ```
#
# This is a rather common way of structuring a project:
#
# * The top-level `modulescicompclass` directory is not part of the python
#   package, but instead is where the source control (e.g. git) begins,
#   and also hosts setup files that are used for installation
#
# * `modulescicompclass/modulescicompclass` is the actual python module that we will load. To make python recognize this as a module, we need an `__init__.py` file there --- it can be completely empty.
#
#
# * The actual `*.py` files that make up our module are in `modulescicompclass/modulescicompclass`
#
# Right now, this package does not appear in our python search path, so
# the only way to load it is to work in the top-level `mymodule/`
# directory (that's because the current directory is *always* in the path).

# %% [markdown]
# ## setuptools
#
# The current python package recommendations are:
#
# * Installation:
#
#   * `pip` to install packages from PyPI
#   * `conda` for distributing cross-platform software stacks (conda is also well integrated with pip)
#
# * Packaging tools:
#
#   * `setuptools` to create source distributions
#   * `build` for binary distributions
#   * `twine` to upload to PyPI
#
# OSS: le raccomandazioni sull'upload dei pacchetti vengono continuamente aggiornate per evitare che le persone carichino installazioni malevoli.
# Let's look at how to use [`setuptools`](https://setuptools.pypa.io/en/latest/index.html) to package our library.  See the
# packaging guidelines here:
# https://packaging.python.org/en/latest/guides/distributing-packages-using-setuptools/
#
# The main thing we need to do is create a `setup.py` that describes our
# package and its requirements:
#
# Here's a first `setup.py`: metadati e istruzioni su nome del modulo, descrizione, autore, licenza, versione, pacchetti richiesti (es. numpy)
#
# ```python
# from setuptools import setup, find_packages
#
# setup(name='modulescicompclass',
#       description='test module for the SciComp class',
#       url='https://github.com/dgerosa',
#       author='Davide Gerosa',
#       author_email='davide.gerosa@unimib.it',
#       license='MIT',
#       version='0.0.1',
#       packages=find_packages(),
#       install_requires=['numpy', 'matplotlib'])
# ```
#
#
# The packaging ecosystem is always evolving (too quickly if you ask me...).  There are 2 special config files that can help customize the package and contain the defaults for other tools: `setup.cfg` and
# `pyproject.toml`.  See:
#
# * [Configuring setuptools using `setup.cfg` files](https://setuptools.pypa.io/en/latest/userguide/declarative_config.html)
#
# * [Configuring setuptools using `pyproject.toml` files](https://setuptools.pypa.io/en/latest/userguide/pyproject_config.html)
# ```

# %% [markdown]
# ## Installing
#
# We can use setup in a variety of ways.  Two useful ways are:
#
# * Install:
#
#   `python setup.py install`
#
#   This will copy the source files into your install location (likely
#   `~/.local/...`) putting them into your python search path.  Then you
#   can use this package from anywhere.
#
# * Development mode (https://setuptools.pypa.io/en/latest/userguide/development_mode.html):
#
#   `python setup.py develop`
#
#   This doesn't actually install anything in your user- or site-wide
#   install location, but instead it creates a special link in that
#   install directory back to your actual project code.
#
#   This allows you to continue to develop the package without needed to
#   re-install each time you change the source.
#
#   You can uninstall via:
#
#   `pip uninstall modulescicompclass`
#
# The above put the package in the system-wide path. Should be ok for your laptop, but if you're on a cluster where you don't have admin privileges use the `--user` flag.
#
#
# ## Using our module
#
# Once the module is installed, we can use it from any directory.  For example, if we do:

# %%
import modulescicompclass    # importo questo modulo per fare la funzione di Mandelbrot

# %%
import modulescicompclass
print(modulescicompclass.__file__)
# Out:
# None

# %%
import numpy
print(numpy.__file__)
# Out:
# /home/michele/python_env/lib/python3.12/site-packages/numpy/__init__.py

# %%
fig = modulescicompclass.mandelbrot(128)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 fig = modulescicompclass.mandelbrot(128)
#
# AttributeError: module 'modulescicompclass' has no attribute 'mandelbrot'

# %% [markdown]
# ## pip Deployment
#
# Making your code pip-installable is now trivial. The one thing left to do is uploading your code to https://pypi.org/ which is where pip looks for information. Bisogna crearsi l'account.
#
# Pypi (Python Package Index) is beautiful because it's open and free, everybody can make their code available! (but that's also free territory for [frauds](https://www.welivesecurity.com/en/eset-research/pernicious-potpourri-python-packages-pypi/), so careful with what you install).
#
#
# You need to create an account on pypi and generate an API token. Instructions [here](https://packaging.python.org/en/latest/tutorials/packaging-projects/).  pypi is the actual pip.
#
# This involves writing a `.pypirc` file in your home directory
#
# ```
# [distutils]
# index-servers =
#     pypi
#     testpypi
#
# [pypi]
# username = __token__
# password: YOUR TOKEN GOES HERE
#
# [testpypi]
# username = __token__
# password: YOUR TOKEN GOES HERE
# ```
#
#
#  Then create the distribution bundle with
#
# ```python setup.py sdist``` to create the distribution bundle contenente tutti i pacchetti che poi uploderò su pypi
#
# Pypi has a test server https://test.pypi.org/ where you can try things out before going to the real pip repository (don't want to mess things up...). Upload with (solo per test prima di inviare al mondo il proprio codice, stessa struttura di pypi)
#
#
# ```twine upload --repository testpypi dist/* #for the test server```
#
# When you're confident everything works
#
# ```twine upload dist/* #for the real pip```
#
# and you're done! Everybody will be able to pip-install and use your code.
#
# Here we are: https://test.pypi.org/project/modulescicompclass/
#
# Anyone can now install this code!
#
#
# ```pip install --index-url https://test.pypi.org/simple modulescicompclass```
#
# If you upload it to the real pip than this becomes
#
# ```pip install modulescicompclass```
#
#
#
# For a complete example from my research have a look at https://github.com/dgerosa/precession which is indeed pip installable.

# %% [markdown]
# **Important**
# - Modules names on pip are unique. When you upload a package for the first time, that name belongs to you and you only. For this reason, when trying to run these instructions you won't be able to upload a package called `modulescicompclass` because that name is mine now. Just change the name.
# - Versioning is also unique. You *cannot* replace a package on pip, only release a newer code bumping the version up. Posso solo aggiornare la versione, non cancellare la precedente, anche se trovo un errore.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# Let me say here that producing good, well documented, and reusable code is *crucial* for being influential in modern research. No point understanding a beautiful piece of physics if nobody else can use it!
#
# </div>

# %% [markdown]
# # Tools to Make Your Life Easier
#
# ## Version control
#
# Put your project under git version control. Just do it.
#
#
# ## Code checkers
#
# There are a number of tools that help check code for formatting and
# syntax errors that are quite useful for developers.  Many projects
# automatically enforce these tools on changes submitted to github.
#
# Many editors have plugins that can automatically run these tools
# as your write your code.
#
# * [flake8](https://flake8.pycqa.org/en/latest/)
#
#   `flake8` is a checker for [PEP 8](https://peps.python.org/pep-0008/)
#   style conformance.  You can turn off checks that you don't like
#   via a [`.flake8`
#   file](https://flake8.pycqa.org/en/latest/user/configuration.html#configuration-locations).
#
# * [pylint](https://pypi.org/project/pylint/)
#
#   `pylint` is a static code analyzer.  It can find errors and also suggest improvements
#   to your code.  You can [generate a configuration file](https://pylint.readthedocs.io/en/latest/user_guide/configuration/index.html)
#   to customize its behavior (or add a section to `pyproject.toml`).
#
# * [black](https://pypi.org/project/black/)
#
#   `black` is an _uncompromising code formatted_.  It will automatically rewrite your code
#   based on PEP-8 style.
#
# * [pyupgrade](https://github.com/asottile/pyupgrade)
#
#   `pyupgrade` will upgrade source to a later python standard, making
#   use of new features where available.  For instance, you can run as:
#
#   ```
#   pyupgrade --py39-plus file.py
#   ```
#
#   to update to python 3.9 support.
#
# * [isort](https://pycqa.github.io/isort/)
#
#   `isort` simply sorts the module imports at the top of your modules,
#   grouping the standard python ones together followed by
#   package-specific ones.

# %% [markdown]
# # Part 2. Unit testing with pytest

# %% [markdown]
# Testing is an integral part of the software development process.  We want to catch
# mistakes early, before the go on to affect our results.
#
# Codice deve essere riproducibile ed evitare bugs. Alcuni sviluppatori hardcore dicono addirittura di scrivere prima i test che il codice. Potenzialmente sarebbe ideale avere un test il 99% del codice
#
# ## Types of testing
#
# There are a lot of different types of software testing that exist.
# Most commonly, for scientific codes, we hear about:
#
# * Unit testing : Tests that a single function does what it was designed to do or a single line, method of class, ...
#
# * Integration testing : Tests whether the individual pieces work together as intended.
#   Sometimes done one piece at a time (iteratively)
#
# * Regression testing : Checks whether changes have changed answers
#
# * Verification & Validation (from the science perspective)
#
#   * Verification: are we solving the equations correctly?
#
#   * Validation: are we solving the correct equations?
#
# ## Automating testing
#
# The best testing is automated.  Github provides a *continuous integration* service that can
# be run on pull requests.  You write a short definition (a Github workflow) that tells Github
# how to run your tests and then any time there is a change, the tests are run.
# Non devo ricordarmi di fare io i test. Come ricordarsi di fare il backup dei dati è meglio se è automatico.
#
# ## Unit testing
#
# * When to write tests?
#
#   * Some people advocate writing a unit test for a specification
#     before you write the functions they will test
#
#     * This is called Test-driven development (TDD):
#       https://en.wikipedia.org/wiki/Test-driven_development
#
#   * This helps you understand the interface, return values,
#     side-effects, etc. of what you intend to write
#
# * Often we already have code, so we can start by writing tests to
#   cover some core functionality
#
#   * Add new tests when you encounter a bug, precisely to ensure that
#     this bug doesn't arise again
#
# * Tests should be short
#
#   * You want to be able to run them frequently

# %% [markdown]
# # pytest
#
# `pytest` is a unit testing framework for python code.
#
# Basic elements:
#
# * Discoverability: it will find the tests
#
# * Automation
#
# * Fixtures (setup and teardown)
#
# ## Installing
#
# You can install `pytest` for a single user as:
#
# ```
# pip install pytest
# ```
#
# This should put `pytest` in your search path, likely in `~/.local/bin`.
#
# If you want to generate coverage reports, you should also install `pytest-cov`:
#
# ```
# pip install pytest-cov
# ```
#
# ## Test discovery
#
# Adhering to these naming conventions will ensure that your tests are automatically found:
#
# * File names should start or end with “test”:
#
#   * `test_example.py`
#   * `example_test.py`
#
# * For tests in a class, the class name should begin with `Test`
#
#   * e.g., `TestExample`
#   * There should be no `__init__()`
#
# * Test method / function names should start with `test_`   -> riconosciuto da python automaticamente come un test
#
#   * e.g., `test_example()`
#
# ## Assertions
#
# Tests use assertions (via python’s `assert` statement) to check behavior at runtime
#
# * https://docs.python.org/3/reference/simple_stmts.html#assert
#
# * Basic usage: `assert expression`
#
#   * Raises `AssertionError` if expression is not true
#
#   * e.g., `assert 1 == 0` will fail with an exception
#
# ## Simple pytest example
#
# Create a file named `multiply_test.py` with the following content:
#
# ```python
# def multiply(a, b):
#     return a*b
#
# def test_multiply():
#     assert multiply(4, 6) == 24
#
# def test_multiply2():
#     assert multiply(5, 6) == 2
# ```
#
# then we can run the tests as:
#
# ```
# pytest -v
# ```
#
# and we get the output:
#
# ```
# ============================= test session starts ==============================
# platform linux -- Python 3.11.3, pytest-7.2.2, pluggy-1.0.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/zingale/temp/pytest
# plugins: anyio-3.6.2
# collected 2 items
#
# test_simple.py::test_multiply PASSED                                     [ 50%]
# test_simple.py::test_multiply2 FAILED                                    [100%]
#
# =================================== FAILURES ===================================
# ________________________________ test_multiply2 ________________________________
#
#     def test_multiply2():
# >       assert multiply(5, 6) == 2
# E       assert 30 == 2
# E        +  where 30 = multiply(5, 6)
#
# test_simple.py:8: AssertionError
# =========================== short test summary info ============================
# FAILED test_simple.py::test_multiply2 - assert 30 == 2
# ========================= 1 failed, 1 passed in 0.04s ==========================
# ```
#
# this is telling us that one of our tests has failed.

# %% [markdown]
# # More pytest
#
# Test is the modern way to debug a code.
#
# Unit tests sometimes require some setup to be done before the test is run.  Fixtures
# provide this capability.
#
# pytest provides `setup` and `teardown` functions/methods for tests --
# see https://docs.pytest.org/en/6.2.x/fixture.html for more details
#
# Note:  By default, pytest will capture stdout and only show it on failures.  If you want
# to always show stdout, add the `-s` flag.
#
#
# ## Example class
#
# Classe di test completa
#
# It is common to use a class to organize a set of related unit tests.  This is
# not a full-fledged class -- it simply helps to organize data.  In particular,
# there is no constructor, `__init__()`.  See https://stackoverflow.com/questions/21430900/py-test-skips-test-class-if-constructor-is-defined
#
# We'll look at an example with a NumPy array
#
# * We always want the array to exist for our tests, so we'll use
#   fixtures (in particular `setup_method()`) to create the array   come costruttore e distruttore di classe in OO
#
# * Using a class means that we can access the array created in setup from our class.
#
# * We'll use numpy's own assertion functions: https://numpy.org/doc/stable/reference/routines.testing.html
#
#
# Here's an example:
#
# ```python
# # a test class is useful to hold data that we might want setup
# # for every test.
#
# import numpy as np
# from numpy.testing import assert_array_equal
#
# class TestClassExample:
#
#     @classmethod
#     def setup_class(cls):
#         """ this is run once for each class, before any tests """
#         pass
#
#     @classmethod
#     def teardown_class(cls):
#         """ this is run once for each class, after all tests """
#         pass
#
#     def setup_method(self):
#         """ this is run before each of the test methods """
#         self.a = np.arange(24).reshape(6, 4)
#
#     def teardown_method(self):
#         """ this is run after each of the test methods """
#         pass
#
#     def test_max(self):
#         assert self.a.max() == 23
#
#     def test_flat(self):
#         assert_array_equal(self.a.flat, np.arange(24))
# ```
#
#
# Here we see the [`@classmethod` decorator](https://docs.python.org/3/library/functions.html#classmethod).
# This means that the function receives the class itself as the first argument rather then an instance,
# e.g., `self`.
#
#
# Put this into a file called `test_class.py` and then we can run as:
#
# ```
# pytest -v
# ```

# %% [markdown]
# ## Modern workflow
#
# Modern code tested is collaborative and automated. Say you found a bug in numpy and want to fix it. You can only pull request to their git repo only if your patch passes a whole suite of tests.
#
# That's for big things, but I argue having some basic unit tests is important for every code, even your little PhD project (and well... if you end up having a pull request merged into numpy, that should go straight into your CV!!!)
#
#
# ## Other types of tests
#
# Unit tests are only one form of testing - they test a function in
# isolation of others.  Sometimes we need to test everything working together.
# For scientific codes, regression testing is often used.  The basic workflow
# is:
#
# * Start with the project working in a way you are happy with
#
# * Store the output of one (or more) runs as a _benchmark_.
#
# * Each time you make changes, run the code and compare the new output
#   to the stored benchmark.
#
#   * If there are no differences, then your changes are likely good
#     (but there is always the case of some feature not being tested).
#
#   * If there are differences, then either you introduced a bug, in which
#     case you should fix it, or you fixed a bug, in which case you should
#     update the benchmarks.

# %% [markdown]
# # Part 3: profiling

# %% [markdown]
# Rendere il codice più veloce (es. evitare loop for, ...)  -> capire dove perdo più tempo
#
# Profiling is the art of figuring out where you're wasting time. If your code is too slow, it's very very rare that the entire code is slow. Often you have one or a few bottlenecks, and rewriting those little pieces will make your life beautiful again. You could then try to make a smarter use on numpy, jit them with Numba, or make them run in parallel, as appropriate.

# %% [markdown]
# The standard python profiling tool is called [cProfile](https://docs.python.org/3/library/profile.html).
#
# This is a random example:

# %%
from scipy.optimize import minimize


def myfunc():
    # c.f. https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html
    func = lambda x: (x[0] - 1) ** 2 + (x[1] - 2.5) ** 2
    x0 = (2, 0)

    constraints = (
        {"type": "ineq", "fun": lambda x: x[0] - 2 * x[1] + 2},
        {"type": "ineq", "fun": lambda x: -x[0] - 2 * x[1] + 6},
        {"type": "ineq", "fun": lambda x: -x[0] + 2 * x[1] + 2},
    )

    bounds = ((0, None), (0, None))

    result = minimize(func, x0, method="SLSQP", bounds=bounds, constraints=constraints)
    print(f"result:\n{result}")
    print(f"best fit parameters: {result.x}")

# %%
myfunc()

# %%
# %%capture   
# nasconde output cell jupyter, qui è lungo

import cProfile 
cProfile.run('myfunc()', sort='cumtime')

# %% [markdown]
# This will tell us exactly where the time goes...

# %%
# This is the same but dumps to file

with cProfile.Profile() as pr:
    myfunc()  

pr.dump_stats('example.prof')

# %% [markdown]
# There's a super nice interface which is called [snakeviz](https://jiffyclub.github.io/snakeviz/). Try this:
#
# ```snakeviz example.prof```
#
# (might need to `pip install snakeviz` first of course)

# %% [markdown]
# ## A complete example from my own research: merging binary black holes
#
# Let's evolve some black-hole binaries from large separations (presumably where they form following stellar collapse) to small separation where they merge and become detectable as gravitational-wave searches.
#
# This is a python module I wrote: https://github.com/dgerosa/precession
#
# The mathematical problem is described here https://arxiv.org/abs/2304.04801
# In short, we need to solve some ordinary differential equations with a RHS that contains some elliptic integrals, and in turn some of the parameters of these elliptic integrals are solutions to some (very long!) polynomials.
#
# **Warning**: don't look at the appendices of that paper before getting a good cup of coffee. And if you do, of course those equations are machine-generated! I used Mathematica to compute the equations, and then exported the results to python.

# %%
pip install precession

# %%
import precession # You need to "pip install precession"
import numpy as np


def blackholes():
    
    N=100
    q=np.random.uniform(0.1,1,N)
    chi1=np.random.uniform(0.1,1,N)
    chi2=np.random.uniform(0.1,1,N)
    theta1=np.arccos(np.random.uniform(-1,1,N))
    theta2=np.arccos(np.random.uniform(-1,1,N))
    deltaphi=np.random.uniform(-np.pi,np.pi,N)
    r=[1000,10]
    
    return  precession.inspiral_precav(theta1=theta1,theta2=theta2,deltaphi=deltaphi,r=precession.tiler(r,q),q=q,chi1=chi1,chi2=chi2)

# %%
# %%capture   
# nasconde output cell jupyter, qui è lungo

blackholes()

# %% [markdown]
# Who cares what that is, let's profile it.

# %%
with cProfile.Profile() as pr:
    blackholes()  

pr.dump_stats('example.prof')

# %% [markdown]
# And now let's have a look where I'm being silly...
#
# ```snakeviz example.prof```
#
# I reported the results of a similar profiling exercise in Sec 6.C (page 19-20) of the paper that describes this code https://arxiv.org/pdf/2304.04801.pdf

# %% [markdown]
# # Exercises
#
# For the exams work on at least two of the these three exercises
#
# ## Q1: I love pip
#
# - Take a piece of python code you wrote (for instance pick one of the exercises you've done for this class).
# - Turn it into a module
# - Install it locally
# - Deploy on pypi (only using the test-pypi server!)
#
# <div class="alert alert-block alert-warning">
# <span class="fa fa-flash"></span> VERY IMPORTANT
#
# Both the pypi and test-pypi server are public on the web! Don't compromise your research by putting up something your competitors can use and steal your idea before you've published a paper on it!!!
#
# </div>

# %%
pip install --index-url https://test.pypi.org/simple/ lymanforest
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: lymanforest in /home/michele/python_env/lib/python3.12/site-packages (0.1.0)
# Requirement already satisfied: numpy in /home/michele/python_env/lib/python3.12/site-packages (from lymanforest) (2.3.5)
# Requirement already satisfied: h5py in /home/michele/python_env/lib/python3.12/site-packages (from lymanforest) (3.15.1)
# Requirement already satisfied: scipy in /home/michele/python_env/lib/python3.12/site-packages (from lymanforest) (1.16.3)
# Requirement already satisfied: numba in /home/michele/python_env/lib/python3.12/site-packages (from lymanforest) (0.62.1)
# Requirement already satisfied: matplotlib in /home/michele/python_env/lib/python3.12/site-packages (from lymanforest) (3.10.7)
# Requirement already satisfied: tqdm in /home/michele/python_env/lib/python3.12/site-packages (from lymanforest) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/michele/python_env/lib/python3.12/site-packages (from matplotlib->lymanforest) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/michele/python_env/lib/python3.12/site-packages (from matplotlib->lymanforest) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/michele/python_env/lib/python3.12/site-packages (from matplotlib->lymanforest) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/michele/python_env/lib/python3.12/site-packages (from matplotlib->lymanforest) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/michele/python_env/lib/python3.12/site-packages (from matplotlib->lymanforest) (25.0)
# Requirement already satisfied: pillow>=8 in /home/michele/python_env/lib/python3.12/site-packages (from matplotlib->lymanforest) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/michele/python_env/lib/python3.12/site-packages (from matplotlib->lymanforest) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/michele/python_env/lib/python3.12/site-packages (from matplotlib->lymanforest) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /home/michele/python_env/lib/python3.12/site-packages (from numba->lymanforest) (0.45.1)
# Requirement already satisfied: six>=1.5 in /home/michele/python_env/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->lymanforest) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import lymanforest
from lymanforest.pipeline import process_snapshot

print(f"Versione installata: {lymanforest.__version__ if hasattr(lymanforest, '__version__') else '0.1.0'}")
print("It works!")
# Out:
# Versione installata: 0.1.0
# It works!

# %% [markdown]
# ## Q2: My own test
#
# - Pick a piece of python code that you like (your own PhD project, or take one of the exercises from this class). Implement a unit test and a regression test.
# - Put it under git version control, and write a github action that runs the tests at every commit.
# - Edit the github options to make sure the code *cannot* be committed if the tests fail (that's a common thing for big projects with many collaborations, nobody is allowed to break the code)

# %% [raw]
# The unitary and regression tests and the github action is in the lymanforest project: https://github.com/MicheleFulghieri/lymanforest

# %% [markdown]
# ## Q3: How do professionals do it?
#
# Pick a big git repo, say [scipy](https://github.com/scipy/scipy) or [numpy](https://github.com/numpy/numpy),  and have a look at their development workflow, including their testing strategies.

# %% [markdown]
# ## Q4: It's over Anakin, I have the high ground.
#
# Pick a piece of your code that your really hate. It's sooooo slooooow.
# - Profile it.
# - Find the culprit
# - Rewrite that bottleneck making a better use of numpy arrays, or jitting it with Numba.
# - Enjoy your faster code
#
# **You underestimate my power**.

# %% [markdown]
# Calculate the total potential energy:$$V = \sum_{i} \sum_{j > i} - \frac{G \cdot m_i \cdot m_j}{|\vec{r}_i - \vec{r}_j|}$$

# %%
# Slow code
import numpy as np
import time

# funcion that calculate the gravitational potential for a system of N particles

def calculate_potential(pos, masses, G=6.67*10**-11):
    """ funcion that calculate the gravitational potential for a system of N particles """

    n = len(masses)    # number of particles
    potential = 0.0    # initialize the potential

    # double for loop (sum over the particles)
    for i in range(n):
        for j in range(i+1, n):
            # calculation of the euclidean distance
            dist = np.sqrt(
                (pos[i, 0] - pos[j, 0])**2 +
                (pos[i, 1] - pos[j, 1])**2 +
                (pos[i, 2] - pos[j, 2])**2                
            )
            potential -= masses[i] * masses[j] / dist
    return potential

# test the function
N = 3000                         # number of particles
pos    = np.random.random((N,3))  
masses = np.random.random(N)

start = time.time()
slow_test = calculate_potential(pos, masses)
print(f"Slow version: {time.time() - start:.4f} seconds")
# Out:
# Slow version: 12.3507 seconds

# %%
# Profiling
import cProfile

cProfile.run('calculate_potential(pos, masses)', sort='cumtime')   # cumtime: cumulative time in seconds
# Out:
#          768 function calls (756 primitive calls) in 13.044 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   12.964   12.964 threading.py:637(wait)
#        12   10.879    0.907   10.879    0.907 {built-in method time.sleep}
#         6    0.000    0.000   10.690    1.782 base_events.py:1910(_run_once)
#         6    0.066    0.011   10.689    1.781 selectors.py:451(select)
#       2/1    0.000    0.000    2.274    2.274 {built-in method builtins.exec}
#       2/1    0.004    0.002    2.274    2.274 <string>:1(<module>)
#         6    1.183    0.197    1.183    0.197 {method 'poll' of 'select.epoll' objects}
#         1    0.835    0.835    0.835    0.835 3537857520.py:7(calculate_potential)
#         1    0.000    0.000    0.052    0.052 decorator.py:232(fun)
#         1    0.023    0.023    0.052    0.052 history.py:100(only_when_enabled)
#         1    0.000    0.000    0.029    0.029 history.py:1055(writeout_cache)
#         1    0.000    0.000    0.028    0.028 history.py:1039(_writeout_input_cache)
#         7    0.000    0.000    0.024    0.003 events.py:86(_run)
#         7    0.000    0.000    0.024    0.003 {method 'run' of '_contextvars.Context' objects}
#         2    0.000    0.000    0.023    0.012 zmqstream.py:573(_handle_events)
#         1    0.000    0.000    0.023    0.023 asyncio.py:206(_handle_events)
#         2    0.000    0.000    0.023    0.011 zmqstream.py:614(_handle_recv)
#         2    0.006    0.003    0.023    0.011 zmqstream.py:546(_run_callback)
#         2    0.018    0.009    0.018    0.009 {method '__exit__' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.017    0.008 iostream.py:229(_handle_event)
#        14    0.017    0.001    0.017    0.001 socket.py:623(send)
#         2    0.000    0.000    0.017    0.008 iostream.py:348(<lambda>)
#         2    0.000    0.000    0.017    0.008 iostream.py:350(_really_send)
#         2    0.000    0.000    0.017    0.008 socket.py:700(send_multipart)
#         1    0.010    0.010    0.010    0.010 {method 'execute' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:190(_run_event_pipe_gc)
#        14    0.000    0.000    0.000    0.000 enum.py:1551(__or__)
#         2    0.000    0.000    0.000    0.000 ioloop.py:750(_run_callback)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:684(<lambda>)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:653(_rebuild_io_state)
#        60    0.000    0.000    0.000    0.000 enum.py:1544(_get_value)
#         4    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         4    0.000    0.000    0.000    0.000 tasks.py:653(sleep)
#         2    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:676(_update_handler)
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#   131/127    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:199(_event_pipe_gc)
#         4    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         2    0.000    0.000    0.000    0.000 futures.py:311(_set_result_unless_cancelled)
#         3    0.000    0.000    0.000    0.000 base_events.py:785(call_soon)
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         6    0.000    0.000    0.000    0.000 enum.py:1562(__and__)
#         3    0.000    0.000    0.000    0.000 base_events.py:814(_call_soon)
#        26    0.000    0.000    0.000    0.000 enum.py:726(__call__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 base_events.py:743(call_later)
#        13    0.000    0.000    0.000    0.000 {built-in method posix.getppid}
#         1    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#         1    0.000    0.000    0.000    0.000 inspect.py:3237(bind)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 iostream.py:682(_flush)
#         5    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         2    0.000    0.000    0.000    0.000 base_events.py:767(call_at)
#         6    0.000    0.000    0.000    0.000 threading.py:1220(is_alive)
#         1    0.000    0.000    0.000    0.000 inspect.py:3102(_bind)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#        13    0.000    0.000    0.000    0.000 base_events.py:734(time)
#         6    0.000    0.000    0.000    0.000 typing.py:392(inner)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         1    0.000    0.000    0.000    0.000 iostream.py:776(_flush_buffers)
#         2    0.000    0.000    0.000    0.000 typing.py:1194(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         1    0.000    0.000    0.000    0.000 inspect.py:2918(apply_defaults)
#        26    0.000    0.000    0.000    0.000 enum.py:1129(__new__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2865(args)
#         2    0.000    0.000    0.000    0.000 iostream.py:288(_check_mp_mode)
#         2    0.000    0.000    0.000    0.000 typing.py:1465(__subclasscheck__)
#         4    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 iostream.py:784(_rotate_buffers)
#         2    0.000    0.000    0.000    0.000 events.py:111(__init__)
#         2    0.000    0.000    0.000    0.000 events.py:155(cancel)
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         7    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#        28    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         6    0.000    0.000    0.000    0.000 threading.py:1153(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         1    0.000    0.000    0.000    0.000 contextlib.py:299(helper)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 iostream.py:285(_is_master_process)
#         4    0.000    0.000    0.000    0.000 typing.py:1258(__hash__)
#        13    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 history.py:1047(_writeout_output_cache)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         4    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         2    0.000    0.000    0.000    0.000 base_events.py:447(create_future)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#         8    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         9    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         8    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         3    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         4    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         2    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         2    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         1    0.000    0.000    0.000    0.000 base_events.py:1895(_add_callback)
#       9/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#        20    0.000    0.000    0.000    0.000 typing.py:2154(cast)
#         3    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 inspect.py:2888(kwargs)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 events.py:72(cancel)
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         9    0.000    0.000    0.000    0.000 base_events.py:2005(get_debug)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         5    0.000    0.000    0.000    0.000 base_events.py:539(_check_closed)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         6    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         4    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         2    0.000    0.000    0.000    0.000 history.py:1100(hold)
#        10    0.000    0.000    0.000    0.000 inspect.py:2777(kind)
#         2    0.000    0.000    0.000    0.000 iostream.py:327(closed)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         4    0.000    0.000    0.000    0.000 inspect.py:3058(parameters)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 base_events.py:1905(_timer_handle_cancelled)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 inspect.py:2765(name)
#         1    0.000    0.000    0.000    0.000 inspect.py:2857(__init__)

# %%
# Numba rewriting
from numba import njit

@njit
def calculate_potential_numba(pos, masses, G=6.67*10**-11):
    """ funcion that calculate the gravitational potential for a system of N particles, 
        same logic of the calculate_potential function, but optimized with numba"""

    n = len(masses)    # number of particles
    potential = 0.0    # initialize the potential

    # double for loop (sum over the particles)
    for i in range(n):
        for j in range(i+1, n):
            # calculation of the euclidean distance
            dist = np.sqrt(
                (pos[i, 0] - pos[j, 0])**2 +
                (pos[i, 1] - pos[j, 1])**2 +
                (pos[i, 2] - pos[j, 2])**2                
            )
            potential -= masses[i] * masses[j] / dist
    return potential


# test the function
start = time.time()
numba_test = calculate_potential_numba(pos, masses)
print(f"Numba version: {time.time() - start:.4f} seconds")
# Out:
# Numba version: 1.7669 seconds

# %%
# Numba version profiling

cProfile.run('calculate_potential_numba(pos, masses)', sort='cumtime')
# Out:
#          210 function calls (209 primitive calls) in 0.038 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 events.py:86(_run)
#         1    0.000    0.000    0.001    0.001 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.001    0.001 asyncio.py:206(_handle_events)
#         1    0.000    0.000    0.001    0.001 zmqstream.py:573(_handle_events)
#         1    0.000    0.000    0.001    0.001 zmqstream.py:614(_handle_recv)
#         1    0.000    0.000    0.001    0.001 zmqstream.py:546(_run_callback)
#         1    0.000    0.000    0.001    0.001 iostream.py:229(_handle_event)
#         1    0.000    0.000    0.001    0.001 iostream.py:348(<lambda>)
#         1    0.001    0.001    0.001    0.001 iostream.py:350(_really_send)
#         1    0.000    0.000    0.000    0.000 decorator.py:232(fun)
#         6    0.000    0.000    0.000    0.000 socket.py:623(send)
#         1    0.000    0.000    0.000    0.000 history.py:100(only_when_enabled)
#         1    0.000    0.000    0.000    0.000 history.py:1055(writeout_cache)
#       2/1    0.036    0.018    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#         6    0.000    0.000    0.000    0.000 enum.py:1551(__or__)
#         1    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         1    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         9    0.000    0.000    0.000    0.000 enum.py:726(__call__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3237(bind)
#        21    0.000    0.000    0.000    0.000 enum.py:1544(_get_value)
#         1    0.000    0.000    0.000    0.000 inspect.py:3102(_bind)
#         9    0.000    0.000    0.000    0.000 enum.py:1129(__new__)
#         1    0.000    0.000    0.000    0.000 iostream.py:288(_check_mp_mode)
#         3    0.000    0.000    0.000    0.000 typing.py:392(inner)
#        43    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 enum.py:1562(__and__)
#         3    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:299(helper)
#         1    0.000    0.000    0.000    0.000 inspect.py:2918(apply_defaults)
#         1    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         2    0.000    0.000    0.000    0.000 typing.py:1258(__hash__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2865(args)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 base_events.py:734(time)
#         1    0.000    0.000    0.000    0.000 iostream.py:285(_is_master_process)
#         3    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 base_events.py:1895(_add_callback)
#         2    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2888(kwargs)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        10    0.000    0.000    0.000    0.000 inspect.py:2777(kind)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 history.py:1100(hold)
#         7    0.000    0.000    0.000    0.000 typing.py:2154(cast)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 inspect.py:3058(parameters)
#         1    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:327(closed)
#         4    0.000    0.000    0.000    0.000 inspect.py:2765(name)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#         1    0.000    0.000    0.000    0.000 inspect.py:2857(__init__)

# %%
# Numpy version 
def calculate_potential_numpy(pos, masses, G=6.67*10**-11):
    # differences between all pairs of coordinates (Matrix N x N x 3): diff[i, j] = pos[i] - pos[j]
    # exploit broadcasting:
    # pos[:, np.newaxis, :] transform (N, 3) in (N, 1, 3)
    # pos[np.newaxis, :, :] transform (N, 3) in (1, N, 3)
    # diff result in a (N, N, 3) matrix, with diff[i,j] the distance between i and j (the diagonal is i-i, is full of zeros)
    diff = pos[:, np.newaxis, :] - pos[np.newaxis, :, :]

    # dstance calculation (NxN) matrix
    dist = np.sqrt(np.sum(diff**2, axis=-1))

    # avoid division by zero (diagonal element)
    np.fill_diagonal(dist, np.inf)

    # calculation of the product of the masses
    m_prod = masses[:, np.newaxis] * masses[np.newaxis, :]

    # insert in the potential formula and divide by 2 (to avoid double counting)
    potential = -0.5 * np.sum(G * m_prod / dist)

    return potential


# test the function
start = time.time()
numba_test = calculate_potential_numpy(pos, masses)
print(f"Numpy version: {time.time() - start:.4f} seconds")
# Out:
# Numpy version: 0.8838 seconds

# %%
# Numpy version profiling

cProfile.run('calculate_potential_numpy(pos, masses)', sort='cumtime')
# Out:
#          810 function calls (802 primitive calls) in 0.492 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         4    0.000    0.000    0.479    0.120 base_events.py:1910(_run_once)
#       2/1    0.000    0.000    0.298    0.298 {built-in method builtins.exec}
#       2/1    0.009    0.004    0.298    0.298 <string>:1(<module>)
#         1    0.066    0.066    0.289    0.289 4188890755.py:2(calculate_potential_numpy)
#         2    0.000    0.000    0.223    0.111 fromnumeric.py:2304(sum)
#         2    0.204    0.102    0.223    0.111 fromnumeric.py:66(_wrapreduction)
#         3    0.000    0.000    0.180    0.060 selectors.py:451(select)
#         3    0.180    0.060    0.180    0.060 {method 'poll' of 'select.epoll' objects}
#         2    0.019    0.009    0.019    0.009 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.010    0.010 decorator.py:232(fun)
#         1    0.002    0.002    0.010    0.010 history.py:100(only_when_enabled)
#         1    0.000    0.000    0.007    0.007 history.py:1055(writeout_cache)
#         1    0.000    0.000    0.007    0.007 history.py:1039(_writeout_input_cache)
#         2    0.007    0.003    0.007    0.003 {method '__exit__' of 'sqlite3.Connection' objects}
#         4    0.000    0.000    0.003    0.001 events.py:86(_run)
#         4    0.000    0.000    0.003    0.001 {method 'run' of '_contextvars.Context' objects}
#         3    0.000    0.000    0.003    0.001 zmqstream.py:573(_handle_events)
#         3    0.000    0.000    0.002    0.001 zmqstream.py:614(_handle_recv)
#         1    0.000    0.000    0.002    0.002 asyncio.py:206(_handle_events)
#         3    0.000    0.000    0.002    0.001 zmqstream.py:546(_run_callback)
#         3    0.000    0.000    0.001    0.000 iostream.py:229(_handle_event)
#         3    0.000    0.000    0.001    0.000 iostream.py:348(<lambda>)
#         3    0.000    0.000    0.001    0.000 iostream.py:350(_really_send)
#         3    0.000    0.000    0.001    0.000 socket.py:700(send_multipart)
#         3    0.000    0.000    0.001    0.000 ioloop.py:750(_run_callback)
#        21    0.001    0.000    0.001    0.000 socket.py:623(send)
#         2    0.000    0.000    0.001    0.000 zmqstream.py:684(<lambda>)
#        21    0.000    0.000    0.001    0.000 enum.py:1551(__or__)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:653(_rebuild_io_state)
#        90    0.000    0.000    0.000    0.000 enum.py:1544(_get_value)
#         6    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:676(_update_handler)
#         3    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#   195/189    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         6    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         9    0.000    0.000    0.000    0.000 enum.py:1562(__and__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        39    0.000    0.000    0.000    0.000 enum.py:726(__call__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         1    0.000    0.000    0.000    0.000 _index_tricks_impl.py:794(fill_diagonal)
#         2    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         3    0.000    0.000    0.000    0.000 typing.py:1194(__instancecheck__)
#         9    0.000    0.000    0.000    0.000 typing.py:392(inner)
#         1    0.000    0.000    0.000    0.000 inspect.py:3237(bind)
#        39    0.000    0.000    0.000    0.000 enum.py:1129(__new__)
#         1    0.000    0.000    0.000    0.000 iostream.py:682(_flush)
#         3    0.000    0.000    0.000    0.000 typing.py:1465(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 base_events.py:785(call_soon)
#         1    0.000    0.000    0.000    0.000 iostream.py:776(_flush_buffers)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 inspect.py:3102(_bind)
#         2    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         2    0.000    0.000    0.000    0.000 base_events.py:814(_call_soon)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         1    0.000    0.000    0.000    0.000 iostream.py:784(_rotate_buffers)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         7    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         6    0.000    0.000    0.000    0.000 typing.py:1258(__hash__)
#         4    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         3    0.000    0.000    0.000    0.000 iostream.py:288(_check_mp_mode)
#         6    0.000    0.000    0.000    0.000 base_events.py:734(time)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.000    0.000 iostream.py:285(_is_master_process)
#         2    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         3    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         4    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#         1    0.000    0.000    0.000    0.000 contextlib.py:299(helper)
#         1    0.000    0.000    0.000    0.000 history.py:1047(_writeout_output_cache)
#         1    0.000    0.000    0.000    0.000 inspect.py:2918(apply_defaults)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         4    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         3    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 inspect.py:2865(args)
#         1    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         3    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#         6    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         7    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         2    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         6    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        21    0.000    0.000    0.000    0.000 typing.py:2154(cast)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2888(kwargs)
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:1895(_add_callback)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getppid}
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2299(_sum_dispatcher)
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         3    0.000    0.000    0.000    0.000 iostream.py:327(closed)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 inspect.py:2777(kind)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 history.py:1100(hold)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 base_events.py:539(_check_closed)
#         4    0.000    0.000    0.000    0.000 inspect.py:3058(parameters)
#         2    0.000    0.000    0.000    0.000 base_events.py:2005(get_debug)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 inspect.py:2765(name)
#         1    0.000    0.000    0.000    0.000 _index_tricks_impl.py:790(_fill_diagonal_dispatcher)
#         1    0.000    0.000    0.000    0.000 inspect.py:2857(__init__)

# %%
# Time visualzation
import matplotlib.pyplot as plt

# Data based on the profiling
labels = ['Naive', 'Numba (JIT)', 'NumPy']
# times in seconds
times = [16.9199, 0.047, 0.625] 

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# --- Bar Chart (Log Scale) ---
colors = ['#ff9999','#66b3ff','#99ff99']
bars = ax1.bar(labels, times, color=colors, edgecolor='black')
ax1.set_yscale('log')                # to appreciate the difference
ax1.set_ylabel('Times (sec) - Log scale')
ax1.set_title('Performance comparaison - Log Scale')
ax1.grid(True, which="both", ls="-", alpha=0.2)

# add the values over the bars
for bar in bars:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval, f'{yval}s', 
             va='bottom', ha='center', fontweight='bold')

# --- Pie chart ---
ax2.pie(times, labels=labels, autopct='%1.1f%%', colors=colors, 
        startangle=140, explode=(0.1, 0, 0))
ax2.set_title('Execution times distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Huge thanks all!

# %% [markdown]
# ... and we're done. Hope you enjoyed this, thanks for showing up. Hope this material is helpful for your PhD. Looking forward to reading your amazing papers on the results you got with some amazing code!
#
# For the exams, rules are on the README.md file in the class repo.
#
# I've very available to chat coding and science with you (my office is U2-2007).
